# %% [markdown]
# <a href="https://colab.research.google.com/github/sukukumaresan2006-blip/Data-Analytics-using-Python-Project/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset

# %%
import pandas as pd

data = {
    'Student': ['Arun', 'Priya', 'Karthik', 'Ravi', 'Divya'],
    'Mathematics': [95, 85, 70, 45, 88],
    'Science': [90, 80, 75, 50, 92],
    'English': [88, 78, 68, 40, 85],
    'Computer_Science': [96, 90, 72, 55, 95]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Student  Mathematics  Science  English  Computer_Science
# 0     Arun           95       90       88                96
# 1    Priya           85       80       78                90
# 2  Karthik           70       75       68                72
# 3     Ravi           45       50       40                55
# 4    Divya           88       92       85                95

# %% [markdown]
# Calculate Average Marks

# %%
import pandas as pd

df['Average'] = df[['Mathematics',
                    'Science',
                    'English',
                    'Computer_Science']].mean(axis=1)

print(df[['Student', 'Average']])
# Out:
#    Student  Average
# 0     Arun    92.25
# 1    Priya    83.25
# 2  Karthik    71.25
# 3     Ravi    47.50
# 4    Divya    90.00

# %% [markdown]
# Calculate Grade

# %%
def grade(avg):
    if avg >= 90:
        return 'A+'
    elif avg >= 80:
        return 'A'
    elif avg >= 70:
        return 'B'
    elif avg >= 60:
        return 'C'
    elif avg >= 50:
        return 'D'
    else:
        return 'F'

df['Grade'] = df['Average'].apply(grade)

print(df[['Student', 'Grade']])
# Out:
#    Student Grade
# 0     Arun    A+
# 1    Priya     A
# 2  Karthik     B
# 3     Ravi     F
# 4    Divya    A+

# %% [markdown]
# Pass/Fail Status

# %%
df['Status'] = df['Average'].apply(
    lambda x: 'Pass' if x >= 50 else 'Fail'
)

print(df[['Student', 'Status']])
# Out:
#    Student Status
# 0     Arun   Pass
# 1    Priya   Pass
# 2  Karthik   Pass
# 3     Ravi   Fail
# 4    Divya   Pass

# %% [markdown]
# Find Topper

# %%
topper = df.loc[df['Average'].idxmax()]

print("Topper Student")
print(topper)
# Out:
# Topper Student
# Student              Arun
# Mathematics            95
# Science                90
# English                88
# Computer_Science       96
# Average             92.25
# Grade                  A+
# Status               Pass
# Name: 0, dtype: object

# %% [markdown]
# Weak Students

# %%
weak_students = df[df['Average'] < 50]

print("Weak Students")
print(weak_students)
# Out:
# Weak Students
#   Student  Mathematics  Science  English  Computer_Science  Average Grade  \
# 3    Ravi           45       50       40                55     47.5     F
#
#   Status
# 3   Fail

# %% [markdown]
# Subject-wise Performance

# %%
subject_avg = df[['Mathematics',
                  'Science',
                  'English',
                  'Computer_Science']].mean()

print(subject_avg)
# Out:
# Mathematics         76.6
# Science             77.4
# English             71.8
# Computer_Science    81.6
# dtype: float64

# %% [markdown]
# Subject-Wise Bar Chart

# %%
import matplotlib.pyplot as plt

subject_avg.plot(kind='bar')

plt.title("Subject-wise Average Marks")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")

plt.show()

# %% [markdown]
# Grade Distribution Pie Chart

# %%
import matplotlib.pyplot as plt

grade_count = df['Grade'].value_counts()

plt.pie(
    grade_count,
    labels=grade_count.index,
    autopct='%1.1f%%'
)

plt.title("Grade Distribution")
plt.show()

# %% [markdown]
# Pass/fail Bar Chart

# %%
import matplotlib.pyplot as plt

status_count = df['Status'].value_counts()

status_count.plot(kind='bar')

plt.title("Pass / Fail Status")
plt.xlabel("Status")
plt.ylabel("Number of Students")

plt.show()
