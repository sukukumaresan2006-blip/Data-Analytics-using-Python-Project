# %% [markdown]
# <a href="https://colab.research.google.com/github/sukukumaresan2006-blip/Data-Analytics-using-Python-Project/blob/main/day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reshape & Transpose

# %%
import numpy as np

arr=np.array([1,2,3,4,5,6])

new_arr=arr.reshape(2,3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# Mean & Median

# %%
import numpy as np

marks=np.array([70,80,90,60])

average=np.mean(marks)

print(average)
# Out:
# 75.0

# %%
salary=np.array([10000,20000,30000,40000,50000])

med=np.median(salary)

print(med)
# Out:
# 30000.0

# %% [markdown]
# Practice: Product sales performance analysis

# %%
import numpy as np

products = ["Laptop", "Mobile", "Tablet", "Headphone", "Smartwatch"]

sales = np.array([120, 250, 80, 150, 100])

print("Total Sales:", np.sum(sales))

print("Average Sales:", np.mean(sales))

print("Highest Sales:", np.max(sales))

print("Lowest Sales:", np.min(sales))

best_index = np.argmax(sales)
print("Best Selling Product:", products[best_index])

print("\nProduct Sales Report")
for i in range(len(products)):
    print(products[i], ":", sales[i])
# Out:
# Total Sales: 700
# Average Sales: 140.0
# Highest Sales: 250
# Lowest Sales: 80
# Best Selling Product: Mobile
#
# Product Sales Report
# Laptop : 120
# Mobile : 250
# Tablet : 80
# Headphone : 150
# Smartwatch : 100
