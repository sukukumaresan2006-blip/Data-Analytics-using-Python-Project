# %% [markdown]
# <a href="https://colab.research.google.com/github/sukukumaresan2006-blip/Data-Analytics-using-Python-Project/blob/main/Day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dashboard

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]

sales = [10000, 12000, 15000, 13000, 18000, 20000]

plt.figure(figsize=(12, 5))

# Line Chart
plt.subplot(1, 2, 1)

plt.plot(months,
         sales,
         marker='o')

plt.title("Sales Trend")
plt.xlabel("Months")
plt.ylabel("Sales")

# Bar Chart
plt.subplot(1, 2, 2)

plt.bar(months,
        sales,
        color="orange")

plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.tight_layout()
plt.show()

# %% [markdown]
# Histograms

# %%
import matplotlib.pyplot as plt

marks = [45, 50, 55, 60, 65, 70, 72, 75, 80, 85, 90, 95]

plt.hist(marks)

plt.title("Student Marks Distribution")

plt.xlabel("Marks")

plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# Scatter Plots

# %%
import matplotlib.pyplot as plt

hours=[1,2,3,4,5,6,7,8,]

marks=[35,40,50,60,65,75,85,95]

plt.scatter(hours,marks)

plt.title("study hours vs marks")

plt.xlabel("study hours")

plt.ylabel("marks")

plt.show()

# %% [markdown]
# Subplots

# %%
import matplotlib.pyplot as plt

plt.subplot(1,2,1)

plt.plot([1,2,3],[10,20,30])

plt.title("Graph 1")

plt.subplot(1,2,2)

plt.plot([1,2,3],[30,20,10])

plt.title("graph 2")

plt.show()
